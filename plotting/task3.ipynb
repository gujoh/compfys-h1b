# %%
# Imports
import numpy as np 
import matplotlib.pyplot as plt
import scipy
import warnings
warnings.filterwarnings("ignore")

# %%
data0001 = np.genfromtxt("../data/task4_1.0e-03.csv", delimiter=",")
datas = [data0001]
dts = [0.001]

# %%
def plot(data, t, dt):
    fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(16, 8))
    fig.suptitle(f"Energy, temperature, pressure, and the lattice constant plotted against time, dt = {dt}")
    ax[0, 0].grid(True)
    ax[0, 0].plot(t, data[:, 0], label="Potential")
    ax[0, 0].plot(t, data[:, 1], label="Kinetic")
    ax[0, 0].plot(t, data[:, 0] + data[:, 1], label="Total")
    ax[0, 0].set_xlabel("Time (ps)")
    ax[0, 0].set_ylabel("Energy (eV)")
    ax[0, 0].legend()
    ax[0, 1].grid(True)
    ax[0, 1].plot(t, np.cumsum(data[:, 2]) / (t / dt), label="Temperature", c="purple")
    ax[0, 1].set_xlabel("Time (ps)")
    ax[0, 1].set_ylabel("Temperature (K)")
    ax[0, 1].legend()
    ax[1, 0].plot(t, np.cumsum(data[:, 3] / 0.00000624) / (t / dt))
    ax[1, 0].grid(True)
    ax[1, 0].set_xlabel("Time (ps)")
    ax[1, 0].set_ylabel("Pressure (bar)")
    ax[1, 1].plot(t, data[:, 4])
    ax[1, 1].set_xlabel("Time (ps)")
    ax[1, 1].set_ylabel("Lattice constant (Å)")
    ax[1, 1].grid(True)
    plt.show()

def plot_positions(data, t, dt):
    fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(16, 8))
    fig.suptitle("The positions of random particles plotted against time")
    ax[0, 0].plot(t, data[:, 5])
    ax[0, 0].plot(t, data[:, 6])
    ax[0, 0].plot(t, data[:, 7])
    ax[0, 0].set_xlabel("Time (ps)")
    ax[0, 0].set_ylabel("Position")
    ax[0, 1].plot(t, data[:, 8])
    ax[0, 1].plot(t, data[:, 9])
    ax[0, 1].plot(t, data[:, 10])
    ax[0, 1].set_xlabel("Time (ps)")
    ax[0, 1].set_ylabel("Position")
    ax[1, 0].plot(t, data[:, 11])
    ax[1, 0].plot(t, data[:, 12])
    ax[1, 0].plot(t, data[:, 13])
    ax[1, 0].set_xlabel("Time (ps)")
    ax[1, 0].set_ylabel("Position")
    ax[1, 1].plot(t, data[:, 14])
    ax[1, 1].plot(t, data[:, 15])
    ax[1, 1].plot(t, data[:, 16])
    ax[1, 1].set_xlabel("Time (ps)")
    ax[1, 1].set_ylabel("Position")
    plt.show()

# %%
for data, dt in zip(datas, dts):
    t = np.arange(0, data.shape[0]) * dt
    print(f"Average temperature: {np.mean(data[:, 2]):.4f}K")
    print(f"Average pressure: {np.mean(data[:, 3]) / 0.00000624:.4f}")
    plot(data, t, dt)
    plot_positions(data, t, dt)
# Out:
# Average temperature: 1252.5392K
# Average pressure: 95.0581
